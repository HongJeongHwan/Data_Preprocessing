# %% [markdown]
# <a href="https://colab.research.google.com/github/HongJeongHwan/Data_Preprocessing/blob/main/%EC%8B%A4%EC%8A%B502%EB%84%A4%EC%9D%B4%EB%B2%84%EA%B2%80%EC%83%89API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## § 네이버 검색 API

# %% [markdown]
# ### ■ 뉴스 데이터 수집

# %% [markdown]
# ### → 샘플소스

# %%
import urllib
import json
import pandas as pd

# ------- 샘플코드 start -------
# 클라이언트 id / secret 등록
client_id = "36q4O8N06hoHTmxDlYIU"
client_secret = "HtT3FMLE7k"

# 검색어 등록
encText = urllib.parse.quote("ChatGPT")

# 호출 url 작성
url = f"https://openapi.naver.com/v1/search/news.json?query={encText}&display=100&start=1&sort=sim" # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 정보 요청 / 수령
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    news_json1 = response.read()
    print(news_json1.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# ------- 샘플코드 end -------

# json --> dict --> DataFrame
news_dict1 = json.loads( news_json1)
news_info1 = news_dict1['items']
df_info1 = pd.DataFrame(news_info1)

# DataFrame --> csv file
file_path = '/content/drive/MyDrive/KDT/데이터수집관리/네이버뉴스.csv'
df_news.to_csv(file_path, encoding='utf-8', index=False)

# %%
# 필요한 라이브러리 임폴트
import urllib

# 클라이언트 id / secret 등록
client_id = "36q4O8N06hoHTmxDlYIU"
client_secret = "HtT3FMLE7k"

# 검색어 등록
encText = urllib.parse.quote("ChatGPT")

# 호출 url 작성
url = f"https://openapi.naver.com/v1/search/news.json?query={encText}&display=100&start=1&sort=sim" # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 정보 요청 / 수령
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    news_json1 = response.read()
    print(news_json1.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
# json 문자열 --> python dict 자료형 변환 --> json.loads() 사용

# 필요한 모듈 임포트
import json

# json.loads() 사용
news_dict1 = json.loads( news_json1)

# 변환된 결과 확인 --> python dict 확인 --> 자료형 확인
print(type(news_dict1))
print('\n')
print(f'변환된 결과값 :\n{news_dict1}')
print('\n')
keys = news_dict1.keys()
print(keys)
print('\n')

# python dict --> 변수['items'] --> values 추출
news_info1 = news_dict1['items']
print(f'변환결과 :\n{news_info1}')

# %%
# 필요한 라이브러리 임폴트
import urllib

# 클라이언트 id / secret 등록
client_id = "36q4O8N06hoHTmxDlYIU"
client_secret = "HtT3FMLE7k"

# 검색어 등록
encText = urllib.parse.quote("ChatGPT")

# 호출 url 작성
url = f"https://openapi.naver.com/v1/search/news.json?query={encText}&display=100&start=101&sort=sim" # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 정보 요청 / 수령
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    news_json2 = response.read()
    print(news_json2.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
# json 문자열 --> python dict 자료형 변환 --> json.loads() 사용

# 필요한 모듈 임포트
import json

# json.loads() 사용
news_dict2 = json.loads( news_json2)

# # 변환된 결과 확인 --> python dict 확인 --> 자료형 확인
# print(type(news_dict1))
# print('\n')
# print(f'변환된 결과값 :\n{news_dict1}')
# print('\n')
# keys = news_dict1.keys()
# print(keys)
# print('\n')

# python dict --> 변수['items'] --> values 추출
news_info2 = news_dict2['items']
print(f'변환결과 :\n{news_info2}')
# Out:
# 변환결과 :
# ...

# %%
# 전체 new 정보 --> pd.DataFrame 자료형 변환

# 필요한 라이브러리 임포트
import pandas as pd

# news_info --> DataFrame으로 변환
news_info = news_info1 + news_info2
df_info = pd.DataFrame(news_info)

df_info1 = pd.DataFrame(news_info1)
df_info2 = pd.DataFrame(news_info2)

# 결과 확인
print(df_info1)
print('\n')
print(df_info2)

# %%
# 데이터프레임 병합
# DataFrame.concat할때 ignore_index=True 해주거나, DataFrame.reset_index(drop=False)를 추가해준다.
df_news = pd.concat([df_info1, df_info2],ignore_index=True)
# df_news.reset_index(drop=False)

# %%
# 수집된 뉴스 데이터 --> csv file 저장

# 파일 경로 설정
file_path = '/content/drive/MyDrive/KDT/데이터수집관리/네이버뉴스.csv'

# csv file로 변환
df_news.to_csv(file_path, encoding='utf-8', index=False)

# %%
import json
import pandas as pd

py_dict1 = json.loads(news_json1)

# print(py_dict1)
# DataFrame으로 만들기
# print(len(py_dict1['items']))

# print(py_dict1['items'])
df_result = pd.DataFrame(py_dict1['items'])
df_result

# %%
# csv파일로 저장하기

# 파일 경로 설정
file_path = '/content/drive/MyDrive/KDT/데이터수집관리/search_news.csv'

# 방법 --> df.to_csv()
# index=True(default) : 인덱스를 컬럼으로 만들어준다.
df_result.to_csv(file_path, encoding='utf-8', index=False)

# %% [markdown]
# ### ■ 블로그 데이터 수집

# %%
# ------- 샘플코드 start -------
# 클라이언트 id / secret 등록
client_id = "36q4O8N06hoHTmxDlYIU"
client_secret = "HtT3FMLE7k"

# 검색어 등록
encText = urllib.parse.quote("데이터 분석")

# 호출 url 작성
url = f"https://openapi.naver.com/v1/search/blog.json?query={encText}&display=100&start=1&sort=sim" # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 정보 요청 / 수령
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    blog_json1 = response.read()
    print(blog_json1.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# ------- 샘플코드 end -------

# %%
# ------- 샘플코드 start -------
# 클라이언트 id / secret 등록
client_id = "36q4O8N06hoHTmxDlYIU"
client_secret = "HtT3FMLE7k"

# 검색어 등록
encText = urllib.parse.quote("데이터 분석")

# 호출 url 작성
url = f"https://openapi.naver.com/v1/search/blog.json?query={encText}&display=100&start=101&sort=sim" # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 정보 요청 / 수령
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    blog_json2 = response.read()
    print(blog_json2.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# ------- 샘플코드 end -------

# %%
dict_blog1 = json.loads(blog_json1)
dict_blog2 = json.loads(blog_json2)

df_blog1 = pd.DataFrame(dict_blog1)
df_blog2 = pd.DataFrame(dict_blog2)

df_blog = pd.concat([df_blog1,df_blog2], ignore_index=True)

file_path = '/content/drive/MyDrive/KDT/데이터수집관리/blog.csv'
df_blog.to_csv(file_path, encoding='utf-8', index=False)

result_df = pd.read_csv(file_path)
result_df
# Out:
#                        lastBuildDate   total  start  display  \
# 0    Fri, 10 Nov 2023 10:56:04 +0900  618167      1      100
# 1    Fri, 10 Nov 2023 10:56:04 +0900  618167      1      100
# 2    Fri, 10 Nov 2023 10:56:04 +0900  618167      1      100
# 3    Fri, 10 Nov 2023 10:56:04 +0900  618167      1      100
# 4    Fri, 10 Nov 2023 10:56:04 +0900  618167      1      100
# ..                               ...     ...    ...      ...
# 195  Fri, 10 Nov 2023 10:56:10 +0900  618167    101      100
# 196  Fri, 10 Nov 2023 10:56:10 +0900  618167    101      100
# 197  Fri, 10 Nov 2023 10:56:10 +0900  618167    101      100
# 198  Fri, 10 Nov 2023 10:56:10 +0900  618167    101      100
# 199  Fri, 10 Nov 2023 10:56:10 +0900  618167    101      100
#
#                                                  items
# 0    {'title': '데이터 유감; 고객 집착과 <b>데이터 분석</b>', 'lin...
# 1    {'title': '빅<b>데이터분석</b>기사 응시자격 4개월 충족하는 방법', ...
# 2    {'title': '빅<b>데이터 분석</b>기사 자격증에 대한 모든것', 'lin...
# ...

# %% [markdown]
# ### ■ 증권 데이터 수집

# %%
# ------- 샘플코드 start -------
# 클라이언트 id / secret 등록
client_id = "36q4O8N06hoHTmxDlYIU"
client_secret = "HtT3FMLE7k"

# 검색어 등록
encText = urllib.parse.quote("ChatGPT")

# 호출 url 작성
url = f"https://openapi.naver.com/v1/search/.json?query={encText}&display=100&start=1&sort=sim" # JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 정보 요청 / 수령
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    stock_json1 = response.read()
    print(stock_json1.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# ------- 샘플코드 end -------
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-36-4413aa27dd05> in <cell line: 16>()
#      14
#      15 # 정보 요청 / 수령
# ---> 16 response = urllib.request.urlopen(request)
#      17 rescode = response.getcode()
#      18 if(rescode==200):
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# ...
